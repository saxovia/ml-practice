# %%
"""from sklearn import datasets

iris = datasets.load_iris()"""
# Out:
# 'from sklearn import datasets\n\niris = datasets.load_iris()'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris') #its from github

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.rcParams['figure.figsize'] = [8,4]
plt.rcParams['figure.dpi'] = 300
iris.plot()
# Out:
# <Axes: >

# %%
iris.plot(logy=True, logx=True)
plt.title('Iris dataset plot')
plt.xlabel('Samples (log scale)')
plt.ylabel('Length/Width')
plt.show()

# %%
x = iris[['sepal_width', 'sepal_length']]
y = iris[['petal_width', 'petal_length']]

# %%
ax = x.plot()
ax2 = y.plot(ax = ax, secondary_y=True)

ax.set_ylabel('Sepal (Width and Length)')
ax2.set_ylabel('Petal (Width and Lenght)')

ax.set_xlabel('#Samples')
ax.set_title('Secondary Axis Plot')
plt.show()

# %%
df = iris.iloc[0][0:4]

# %%
df.plot(kind='bar')

df.plot.bar()
df.plot.bar(color='red', fontsize=5, title=':3', ylabel='length/width', legend=True, 
            ylim=(0,7), grid=True, rot=30) #rot as in rotate labels
# Out:
# <Axes: title={'center': ':3'}, ylabel='length/width'>

# %%
df = iris.head()
df.plot.bar(fontsize=5, title=':3', ylabel='length/width', legend=True, 
            ylim=(0,12), stacked=True, color= ['red', 'orange', 'purple', 'blue'])
plt.legend(bbox_to_anchor=(1.5,1))
plt.show()

# %%
iris.plot.hist()
iris.plot(kind='hist', bins=30, stacked=True, orientation='horizontal') #bins=30: This argument specifies the number of bins (intervals or bars) to use in the histogram4,8.
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris['sepal_width'].plot(kind='hist', bins=30, stacked=True, orientation='horizontal') #bins=30: This argument specifies the number of bins (intervals or bars) to use in the histogram4,8.
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.plot.box(color=dict(boxes='red', whiskers='darkorange', medians='darkblue', caps='purple'), patch_artist=False, vert=True)
# Out:
# <Axes: >

# %%
#iris.plot.area()
ax = iris.plot(kind='area', stacked=True, alpha=0.5)

# %%
#iris.plot(kind='scatter', x ='sepal_width', y='sepal_length')
iris['ratio'] = iris['petal_length'] / iris['petal_width']
iris[iris['species']=='setosa'].plot.scatter(x ='sepal_width', y='sepal_length', c='ratio')
plt.show()

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.plot.hexbin(x ='sepal_width', y='sepal_length', C='ratio', gridsize=10, cmap='viridis') #capital C
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
df = iris.drop('species', axis=1)
df.iloc[0].plot.pie(fontsize=5)
# Out:
# <Axes: ylabel='0'>

# %%
#df.drop(columns=['ratio'], inplace=True)
ax = df.head(3).T.plot.pie(fontsize=5, subplots=True, legend=True)
plt.tight_layout()

# %%
from pandas.plotting import scatter_matrix

# %%
axes = scatter_matrix(df, diagonal='kde', color='red')
for ax in axes:
    ax[0].yaxis.label.set_rotation(80)
    ax[0].yaxis.label.set_ha('right')
plt.tight_layout()

# %%
ax = df.plot(subplots=True, sharex=False, layout=(2,2))
ax = df.plot(subplots=True, sharex=False)
