# %%
import pandas as pd

# %% [markdown]
# ## Arrays, Series

# %%
flavors = ['mango', 'cherry', 'vanilla']
pd.Series(flavors)
pd.Series([1,2,3,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s = pd.Series([1,2,3, 'something'])
s[0], s[3], type(s[0]), type(s[3]), s.dtype
# Out:
# (1, 'something', int, str, dtype('O'))

# %% [markdown]
# ## Dictionary

# %%
a = {'b':2, 'c':3}
pd.Series(a)
# Out:
# b    2
# c    3
# dtype: int64

# %%
s = pd.Series(a, index=['b', 'c'])

# %%
s.max(), s.min(), s.std(), s.mean(), s.var()
# Out:
# (3, 2, 0.7071067811865476, 2.5, 0.5)

# %% [markdown]
# ## Reading files
# By pressing tab you can get all functions related to the one you're searching.<br>
# Shift + double tab inside a function to look at it's quick documentation.

# %%
s = pd.read_csv('data/performancedata.csv', usecols=['Age']).squeeze()
s, type(s)
#squeeze converts it to a series from dataframe. You can only choose one coloumn at a time to use squeeze()
# Out:
# (0       17
#  1       18
#  2       15
#  3       17
#  4       17
#          ..
#  2387    18
#  2388    17
#  2389    16
#  2390    16
#  2391    16
#  Name: Age, Length: 2392, dtype: int64,
#  pandas.core.series.Series)

# %%
s.sum(), s.mean(), s.var(),  s.std(), s.median(), s.min(), s.max()
# Out:
# (39393,
#  16.468645484949832,
#  1.2629227985659897,
#  1.1237983798555635,
#  16.0,
#  15,
#  18)

# %%
s.sort_values(ascending=False) #or sorted(s). list() to convert it to an array, similarly with dict()
# Out:
# 707     18
# 1916    18
# 706     18
# 708     18
# 709     18
#         ..
# 844     15
# 1829    15
# 842     15
# 1831    15
# 1903    15
# Name: Age, Length: 2392, dtype: int64

# %% [markdown]
# ## .apply()

# %%
s.apply(type)
# Out:
# 0       <class 'int'>
# 1       <class 'int'>
# 2       <class 'int'>
# 3       <class 'int'>
# 4       <class 'int'>
#             ...
# 2387    <class 'int'>
# 2388    <class 'int'>
# 2389    <class 'int'>
# 2390    <class 'int'>
# 2391    <class 'int'>
# Name: Age, Length: 2392, dtype: object

# %%
s = pd.read_csv('data/sales.csv', usecols=['Product Name']).squeeze()
s, type(s)
s.apply(len)
# Out:
# 0      13
# 1      16
# 2      16
# 3      17
# 4      23
#        ..
# 235    47
# 236    25
# 237    38
# 238    36
# 239    26
# Name: Product Name, Length: 240, dtype: int64

# %%
s.head()
# Out:
# 0              iPhone 14 Pro
# 1           Dyson V11 Vacuum
# 2           Levi's 501 Jeans
# 3          The Da Vinci Code
# 4    Neutrogena Skincare Set
# Name: Product Name, dtype: object

# %%
s.apply(lambda x: x.split())
# Out:
# 0                                      [iPhone, 14, Pro]
# 1                                   [Dyson, V11, Vacuum]
# 2                                   [Levi's, 501, Jeans]
# 3                                 [The, Da, Vinci, Code]
# 4                            [Neutrogena, Skincare, Set]
#                              ...
# 235    [Nespresso, Vertuo, Next, Coffee, and, Espress...
# 236                      [Nike, Air, Force, 1, Sneakers]
# 237        [The, Handmaid's, Tale, by, Margaret, Atwood]
# 238          [Sunday, Riley, Luna, Sleeping, Night, Oil]
# 239                     [Yeti, Rambler, 20, oz, Tumbler]
# Name: Product Name, Length: 240, dtype: object

# %%
s.apply(str.lower), s.apply(str.title), s.apply(str.split)
# Out:
# (0                                        iphone 14 pro
#  1                                     dyson v11 vacuum
#  2                                     levi's 501 jeans
#  3                                    the da vinci code
#  4                              neutrogena skincare set
#                              ...
#  235    nespresso vertuo next coffee and espresso maker
#  236                          nike air force 1 sneakers
#  237             the handmaid's tale by margaret atwood
#  238               sunday riley luna sleeping night oil
#  239                         yeti rambler 20 oz tumbler
#  Name: Product Name, Length: 240, dtype: object,
#  0                                        Iphone 14 Pro
#  1                                     Dyson V11 Vacuum
#  2                                     Levi'S 501 Jeans
#  3                                    The Da Vinci Code
#  4                              Neutrogena Skincare Set
#                              ...
#  235    Nespresso Vertuo Next Coffee And Espresso Maker
#  236                          Nike Air Force 1 Sneakers
#  237             The Handmaid'S Tale By Margaret Atwood
#  238               Sunday Riley Luna Sleeping Night Oil
#  239                         Yeti Rambler 20 Oz Tumbler
#  Name: Product Name, Length: 240, dtype: object,
#  0                                      [iPhone, 14, Pro]
#  1                                   [Dyson, V11, Vacuum]
#  2                                   [Levi's, 501, Jeans]
#  3                                 [The, Da, Vinci, Code]
#  4                            [Neutrogena, Skincare, Set]
#                               ...
#  235    [Nespresso, Vertuo, Next, Coffee, and, Espress...
#  236                      [Nike, Air, Force, 1, Sneakers]
#  237        [The, Handmaid's, Tale, by, Margaret, Atwood]
#  238          [Sunday, Riley, Luna, Sleeping, Night, Oil]
#  239                     [Yeti, Rambler, 20, oz, Tumbler]
#  Name: Product Name, Length: 240, dtype: object)

# %% [markdown]
# ## DataFrame

# %%
a = {'one' : 1 , 'two' : 2, 'three' : 3}

pd.DataFrame([a]) #must be passed like [] if its a dict
# Out:
#    one  two  three
# 0    1    2      3

# %%
df = pd.DataFrame([a]).T
df
# Out:
#        0
# one    1
# two    2
# three  3

# %%
a = ['one', 'two', 'three']
pd.DataFrame(a, columns =['numbers'])
# Out:
#   numbers
# 0     one
# 1     two
# 2   three

# %%
a = [['one', 1], ['two', 2], ['three', 3]]
df = pd.DataFrame(a, columns=['string', 'numbers'])

# %%
df = pd.read_csv('data/sales.csv')
df.shape
# Out:
# (240, 9)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
df.tail(2), df.head(2)
# Out:
# (     Transaction ID        Date Product Category  \
#  238           10239  2024-08-26  Beauty Products
#  239           10240  2024-08-27           Sports
#
#                               Product Name  Units Sold  Unit Price  \
#  238  Sunday Riley Luna Sleeping Night Oil           1       55.00
#  239            Yeti Rambler 20 oz Tumbler           2       29.99
#
#       Total Revenue  Region Payment Method
#  238          55.00  Europe         PayPal
#  239          59.98    Asia    Credit Card  ,
#     Transaction ID        Date Product Category      Product Name  Units Sold  \
#  0           10001  2024-01-01      Electronics     iPhone 14 Pro           2
#  1           10002  2024-01-02  Home Appliances  Dyson V11 Vacuum           1
#
#     Unit Price  Total Revenue         Region Payment Method
#  0      999.99        1999.98  North America    Credit Card
#  1      499.99         499.99         Europe         PayPal  )

# %%
df.sample(3) #randomly picks any 3 rows from the dataframe
# Out:
#      Transaction ID        Date Product Category  \
# 121           10122  2024-05-01  Home Appliances
# 5             10006  2024-01-06           Sports
# 92            10093  2024-04-02         Clothing
#
#                              Product Name  Units Sold  Unit Price  \
# 121  Hamilton Beach FlexBrew Coffee Maker           1       89.99
# 5             Wilson Evolution Basketball           5       29.99
# 92    Adidas Originals Superstar Sneakers           4       79.99
#
#      Total Revenue  Region Payment Method
# 121          89.99  Europe         PayPal
# 5           149.95    Asia    Credit Card
# 92          319.96    Asia     Debit Card

# %%
df.shape, df.ndim, len(df), df.dtypes
# Out:
# ((240, 9),
#  2,
#  240,
#  Transaction ID        int64
#  Date                 object
#  Product Category     object
#  Product Name         object
#  Units Sold            int64
#  Unit Price          float64
#  Total Revenue       float64
#  Region               object
#  Payment Method       object
#  dtype: object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    object
#  2   Product Category  240 non-null    object
#  3   Product Name      240 non-null    object
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    object
#  8   Payment Method    240 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 17.0+ KB

# %%
df.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
salesfile = pd.read_csv('data/sales.csv')
salesfile.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
salesfile['Units Sold'], type(salesfile['Units Sold']), type(salesfile['Units Sold']), salesfile['Units Sold'].dtype
# Out:
# (0      2
#  1      1
#  2      3
#  3      4
#  4      1
#        ..
#  235    1
#  236    3
#  237    3
#  238    1
#  239    2
#  Name: Units Sold, Length: 240, dtype: int64,
#  pandas.core.series.Series,
#  pandas.core.series.Series,
#  dtype('int64'))

# %% [markdown]
# ### Coloumn manipulation

# %%
salesfile[['Units Sold', 'Product Name']]
# Out:
#      Units Sold                                     Product Name
# 0             2                                    iPhone 14 Pro
# 1             1                                 Dyson V11 Vacuum
# 2             3                                 Levi's 501 Jeans
# 3             4                                The Da Vinci Code
# 4             1                          Neutrogena Skincare Set
# ..          ...                                              ...
# 235           1  Nespresso Vertuo Next Coffee and Espresso Maker
# 236           3                        Nike Air Force 1 Sneakers
# 237           3           The Handmaid's Tale by Margaret Atwood
# 238           1             Sunday Riley Luna Sleeping Night Oil
# 239           2                       Yeti Rambler 20 oz Tumbler
#
# [240 rows x 2 columns]

# %%
salesfile['Something'] = 'Nothing'
salesfile
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# 3                                  The Da Vinci Code           4       15.99
# 4                            Neutrogena Skincare Set           1       89.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method Something
# 0          1999.98  North America    Credit Card   Nothing
# 1           499.99         Europe         PayPal   Nothing
# 2           209.97           Asia     Debit Card   Nothing
# 3            63.96  North America    Credit Card   Nothing
# 4            89.99         Europe         PayPal   Nothing
# ..             ...            ...            ...       ...
# 235         159.99         Europe         PayPal   Nothing
# 236         270.00           Asia     Debit Card   Nothing
# 237          32.97  North America    Credit Card   Nothing
# 238          55.00         Europe         PayPal   Nothing
# 239          59.98           Asia    Credit Card   Nothing
#
# [240 rows x 10 columns]

# %%
salesfile.drop(['Something'], axis=1, inplace = True) #axis 0 means it drop rows, axis 1 means it drop columns
#inplace means whether the operation returns a new DataFrame or modifies the existing DataFrame, true means it modifies the original, false means it makes a new DataFrame
salesfile.head(2)
# Out:
#    Transaction ID        Date Product Category      Product Name  Units Sold  \
# 0           10001  2024-01-01      Electronics     iPhone 14 Pro           2
# 1           10002  2024-01-02  Home Appliances  Dyson V11 Vacuum           1
#
#    Unit Price  Total Revenue         Region Payment Method
# 0      999.99        1999.98  North America    Credit Card
# 1      499.99         499.99         Europe         PayPal

# %%
months = salesfile['Date'].str.split('-').str.get(1) #you must use get(), since if you use [1] it just returns the second row
months = months.astype(int)

# %%
#salesfile.drop(['Month'], axis=1, inplace = True) #needed to drop because it existed previously
salesfile.insert(0, column='Month', value= months)
salesfile
# Out:
#      Month  Transaction ID        Date Product Category  \
# 0        1           10001  2024-01-01      Electronics
# 1        1           10002  2024-01-02  Home Appliances
# 2        1           10003  2024-01-03         Clothing
# 3        1           10004  2024-01-04            Books
# 4        1           10005  2024-01-05  Beauty Products
# ..     ...             ...         ...              ...
# 235      8           10236  2024-08-23  Home Appliances
# 236      8           10237  2024-08-24         Clothing
# 237      8           10238  2024-08-25            Books
# 238      8           10239  2024-08-26  Beauty Products
# 239      8           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# 3                                  The Da Vinci Code           4       15.99
# 4                            Neutrogena Skincare Set           1       89.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 0          1999.98  North America    Credit Card
# 1           499.99         Europe         PayPal
# 2           209.97           Asia     Debit Card
# 3            63.96  North America    Credit Card
# 4            89.99         Europe         PayPal
# ..             ...            ...            ...
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# 238          55.00         Europe         PayPal
# 239          59.98           Asia    Credit Card
#
# [240 rows x 10 columns]

# %%
salesfile['Units Sold'] + 10 #or salesfile['Units Sold'].add(10)
salesfile['Units Sold'] * 10
# Out:
# 0      20
# 1      10
# 2      30
# 3      40
# 4      10
#        ..
# 235    10
# 236    30
# 237    30
# 238    10
# 239    20
# Name: Units Sold, Length: 240, dtype: int64

# %% [markdown]
# ### Handling NULLs

# %%
unis = pd.read_csv('data/uk_universities.csv')
unis.info()
'Total null unis:', unis.isnull().sum(), 'Non Null unis:', unis.notnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 21 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   University_name                                131 non-null    object
#  1   Region                                         131 non-null    object
#  2   Founded_year                                   131 non-null    int64
#  3   Motto                                          114 non-null    object
#  4   UK_rank                                        131 non-null    int64
#  5   World_rank                                     131 non-null    int64
#  6   CWUR_score                                     84 non-null     float64
#  7   Minimum_IELTS_score                            131 non-null    float64
#  8   UG_average_fees_(in_pounds)                    131 non-null    int64
#  9   PG_average_fees_(in_pounds)                    131 non-null    int64
#  10  International_students                         131 non-null    object
#  11  Student_satisfaction                           131 non-null    object
#  12  Student_enrollment                             131 non-null    object
#  13  Academic_staff                                 131 non-null    object
#  14  Control_type                                   131 non-null    object
#  15  Academic_Calender                              105 non-null    object
#  16  Campus_setting                                 113 non-null    object
#  17  Estimated_cost_of_living_per_year_(in_pounds)  131 non-null    int64
#  18  Latitude                                       131 non-null    float64
#  19  Longitude                                      131 non-null    float64
#  20  Website                                        131 non-null    object
# dtypes: float64(4), int64(6), object(11)
# memory usage: 21.6+ KB
# ('Total null unis:',
#  University_name                                   0
#  Region                                            0
#  Founded_year                                      0
#  Motto                                            17
#  UK_rank                                           0
#  World_rank                                        0
#  CWUR_score                                       47
#  Minimum_IELTS_score                               0
#  UG_average_fees_(in_pounds)                       0
#  PG_average_fees_(in_pounds)                       0
#  International_students                            0
#  Student_satisfaction                              0
#  Student_enrollment                                0
#  Academic_staff                                    0
#  Control_type                                      0
#  Academic_Calender                                26
#  Campus_setting                                   18
#  Estimated_cost_of_living_per_year_(in_pounds)     0
#  Latitude                                          0
#  Longitude                                         0
#  Website                                           0
#  dtype: int64,
#  'Non Null unis:',
#  University_name                                  131
#  Region                                           131
#  Founded_year                                     131
#  Motto                                            114
#  UK_rank                                          131
#  World_rank                                       131
#  CWUR_score                                        84
#  Minimum_IELTS_score                              131
#  UG_average_fees_(in_pounds)                      131
#  PG_average_fees_(in_pounds)                      131
#  International_students                           131
#  Student_satisfaction                             131
#  Student_enrollment                               131
#  Academic_staff                                   131
#  Control_type                                     131
#  Academic_Calender                                105
#  Campus_setting                                   113
#  Estimated_cost_of_living_per_year_(in_pounds)    131
#  Latitude                                         131
#  Longitude                                        131
#  Website                                          131
#  dtype: int64)

# %%
unis.fillna(0, inplace=True) #fills all nulls with 0
unis.isnull().sum()
# Out:
# University_name                                  0
# Region                                           0
# Founded_year                                     0
# Motto                                            0
# UK_rank                                          0
# World_rank                                       0
# CWUR_score                                       0
# Minimum_IELTS_score                              0
# UG_average_fees_(in_pounds)                      0
# PG_average_fees_(in_pounds)                      0
# International_students                           0
# Student_satisfaction                             0
# Student_enrollment                               0
# Academic_staff                                   0
# Control_type                                     0
# Academic_Calender                                0
# Campus_setting                                   0
# Estimated_cost_of_living_per_year_(in_pounds)    0
# Latitude                                         0
# Longitude                                        0
# Website                                          0
# dtype: int64

# %%
unis = pd.read_csv('data/uk_universities.csv')
unis['Motto'] = unis['Motto'].fillna('No motto')
unis
# Out:
#                     University_name              Region  Founded_year  \
# 0           University of Cambridge     East of England          1209
# 1              University of Oxford  South East England          1096
# 2          University of St Andrews            Scotland          1413
# 3           Imperial College London              London          1907
# 4           Loughborough University       East Midlands          1966
# ..                              ...                 ...           ...
# 126       University of East London              London          1992
# 127      University of Bedfordshire     East of England          2006
# 128           University of Suffolk     East of England          2007
# 129      Wrexham Glyndwr University               Wales          2008
# 130  Ravensbourne University London              London          1962
#
#                                                  Motto  UK_rank  World_rank  \
# 0                 From here, light and sacred draughts        1           4
# 1                                 The Lord is my light        2           2
# 2                                        Ever to excel        3          86
# 3    Knowledge is the adornment and safeguard of th...        4           8
# 4                     With Truth, Knowledge and Labour        5         404
# ..                                                 ...      ...         ...
# 126                    Science and fulfillment of vows      127         971
# 127                                           No motto      128        1281
# 128                              Honesty and diligence      129        4030
# 129                       Confidence through Education      130        2397
# 130                              Designed for industry      131        2759
#
#      CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0          94.1                  6.5                        21750
# 1          93.3                  6.5                        21770
# 2          75.8                  6.5                        17040
# 3          86.6                  6.5                        23500
# 4          72.8                  5.5                        16400
# ..          ...                  ...                          ...
# 126         NaN                  4.5                        10700
# 127         NaN                  4.5                         9750
# 128         NaN                  4.5                         9495
# 129         NaN                  4.5                        10250
# 130         NaN                  5.5                         9250
#
#      PG_average_fees_(in_pounds)  ... Student_satisfaction Student_enrollment  \
# 0                          23187  ...               85.50%      20,000-24,999
# 1                          19888  ...               86.50%      25,000-29,999
# 2                          15440  ...               87.90%      10,000-14,999
# 3                          29900  ...               77.90%      15,000-19,999
# 4                          16400  ...               85.80%      15,000-19,999
# ..                           ...  ...                  ...                ...
# 126                        11700  ...               76.10%      10,000-14,999
# 127                         9900  ...               77.40%      10,000-14,999
# 128                         9495  ...               76.00%        7,000-7,999
# 129                        10500  ...               74.30%        5,000-5,999
# 130                         9250  ...               66.10%        2,000-2,999
#
#     Academic_staff Control_type Academic_Calender Campus_setting  \
# 0       over-5,000       Public        Trimesters          Urban
# 1       over-5,000       Public        Trimesters          Urban
# 2      1,000-1,499       Public         Semesters       Suburban
# 3      4,000-4,499       Public        Continuous          Urban
# 4      1,500-1,999       Public         Semesters       Suburban
# ..             ...          ...               ...            ...
# 126        900-999       Public         Semesters       Suburban
# 127        500-599       Public         Semesters          Urban
# 128        200-299       Public               NaN            NaN
# 129        200-299       Public               NaN          Urban
# 130        100-199       Public         Semesters          Urban
#
#     Estimated_cost_of_living_per_year_(in_pounds)  Latitude  Longitude  \
# 0                                           12000   52.2054     0.1132
# 1                                           11500   51.7548    -1.2544
# 2                                           12000   56.3417    -2.7943
# 3                                           10700   51.4988    -0.1749
# 4                                            9398   52.7650    -1.2321
# ..                                            ...       ...        ...
# 126                                         10229   51.5076     0.0651
# 127                                          9415   51.8779    -0.4093
# 128                                          9415   52.0523     1.1629
# 129                                          7771   53.0526    -3.0062
# 130                                         10229   51.5017     0.0055
#
#                     Website
# 0             www.cam.ac.uk
# 1              www.ox.ac.uk
# 2      www.st-andrews.ac.uk
# 3              www.ic.ac.uk
# 4          www.lboro.ac.uk/
# ..                      ...
# 126           www.uel.ac.uk
# 127          www.beds.ac.uk
# 128          www.ucs.ac.uk/
# 129      www.glyndwr.ac.uk/
# 130  www.ravensbourne.ac.uk
#
# [131 rows x 21 columns]

# %% [markdown]
# ### Queries

# %%
unis[unis['Founded_year'] == 1992]
unis[unis['University_name'].str.contains('Nottingham')]

unis[unis['Founded_year'] > 1950]
unis[(unis['World_rank'] < 100) & (unis['Founded_year'] > 1950)]
# Out:
#                     University_name              Region  Founded_year  \
# 9             University of Warwick       West Midlands          1965
# 11             University of Exeter  South West England          1955
# 48  Queen Mary University of London              London          1989
#
#                   Motto  UK_rank  World_rank  CWUR_score  Minimum_IELTS_score  \
# 9     Mind Moves matter       10          80        79.3                  5.5
# 11  We follow the light       12          93        77.4                  5.5
# 48    With united power       49          98        79.9                  5.5
#
#     UG_average_fees_(in_pounds)  PG_average_fees_(in_pounds)  ...  \
# 9                         15820                        24500  ...
# 11                        15500                        15500  ...
# 48                        13650                        13950  ...
#
#    Student_satisfaction Student_enrollment Academic_staff Control_type  \
# 9                79.20%      25,000-29,999    2,500-2,999       Public
# 11               80.10%      25,000-29,999    2,500-2,999       Public
# 48               74.30%      20,000-24,999    3,000-3,499       Public
#
#    Academic_Calender Campus_setting  \
# 9         Trimesters       Suburban
# 11         Semesters       Suburban
# 48         Semesters          Urban
#
#    Estimated_cost_of_living_per_year_(in_pounds)  Latitude  Longitude  \
# 9                                           9580   52.3793    -1.5615
# 11                                          8400   50.7371    -3.5351
# 48                                          9500   51.5241    -0.0404
#
#               Website
# 9   www.warwick.ac.uk
# 11   www.exeter.ac.uk
# 48      www.qmw.ac.uk
#
# [3 rows x 21 columns]

# %%
unis[unis['World_rank'].between(1,10, inclusive='both')] #can be neither or both, it's just the way you give the intervals () or []
# Out:
#            University_name              Region  Founded_year  \
# 0  University of Cambridge     East of England          1209
# 1     University of Oxford  South East England          1096
# 3  Imperial College London              London          1907
#
#                                                Motto  UK_rank  World_rank  \
# 0               From here, light and sacred draughts        1           4
# 1                               The Lord is my light        2           2
# 3  Knowledge is the adornment and safeguard of th...        4           8
#
#    CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0        94.1                  6.5                        21750
# 1        93.3                  6.5                        21770
# 3        86.6                  6.5                        23500
#
#    PG_average_fees_(in_pounds)  ... Student_satisfaction Student_enrollment  \
# 0                        23187  ...               85.50%      20,000-24,999
# 1                        19888  ...               86.50%      25,000-29,999
# 3                        29900  ...               77.90%      15,000-19,999
#
#   Academic_staff Control_type Academic_Calender Campus_setting  \
# 0     over-5,000       Public        Trimesters          Urban
# 1     over-5,000       Public        Trimesters          Urban
# 3    4,000-4,499       Public        Continuous          Urban
#
#   Estimated_cost_of_living_per_year_(in_pounds)  Latitude  Longitude  \
# 0                                         12000   52.2054     0.1132
# 1                                         11500   51.7548    -1.2544
# 3                                         10700   51.4988    -0.1749
#
#          Website
# 0  www.cam.ac.uk
# 1   www.ox.ac.uk
# 3   www.ic.ac.uk
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Handling duplication

# %%
df = pd.concat([unis, unis])
df.duplicated().sum(), unis.duplicated().sum()
# Out:
# (131, 0)

# %%
df[~df.duplicated()]
df.drop_duplicates(inplace=True) #both of these remove duplicates
df.duplicated().sum()
# Out:
# 0

# %%
unis['University_name'].value_counts() #gives back how many unique values are present
# Out:
# University_name
# University of Cambridge           1
# Abertay University                1
# Glasgow Caledonian University     1
# Birmingham City University        1
# University of Gloucestershire     1
#                                  ..
# University of Reading             1
# University of Sussex              1
# University of Essex               1
# University of Strathclyde         1
# Ravensbourne University London    1
# Name: count, Length: 131, dtype: int64

# %%
unis['University_name'].unique()
# Out:
# array(['University of Cambridge', 'University of Oxford',
#        'University of St Andrews', 'Imperial College London',
#        'Loughborough University',
#        'London School of Economics and Political Science',
#        'Durham University', 'Lancaster University',
#        'University College London', 'University of Warwick',
#        'University of Bath', 'University of Exeter',
#        'University of Leeds', 'University of Birmingham',
#        'University of Bristol', 'University of Glasgow',
#        'Harper Adams University', 'University of Manchester',
#        'Royal Holloway, University of London',
#        'University of Southampton', 'University of Nottingham',
#        'University of York', 'University of East Anglia UEA',
#        'University of Dundee', 'University of Edinburgh',
#        'University of Sheffield', 'University of Aberdeen',
#        'Newcastle University', 'University of Liverpool',
#        "King's College London", 'Swansea University',
#        'University of Surrey', 'Heriot-Watt University',
#        'Cardiff University', "Queen's University Belfast",
#        'University of Strathclyde', 'University of Essex',
#        'University of Sussex', 'University of Reading',
#        'Nottingham Trent University', 'University of Leicester',
#        'University for the Creative Arts', 'Arts University Bournemouth',
#        'SOAS, University of London', 'Aberystwyth University',
#        'Keele University', 'University of Stirling', 'Aston University',
#        'Queen Mary University of London', 'Coventry University',
#        'University of Lincoln', 'University of West London',
#        'Staffordshire University', 'University of Kent',
#        'Edge Hill University', 'Leeds Arts University',
#        'University of Portsmouth', 'University of the West of England',
#        'University of Ulster', 'Liverpool Hope University',
#        'University of Huddersfield', 'Manchester Metropolitan University',
#        'Norwich University of the Arts', 'Oxford Brookes University',
#        'Northumbria University', 'Sheffield Hallam University',
#        "St George's University of London",
#        'Goldsmiths, University of London', 'University of Roehampton',
#        'Bangor University', 'University of Chichester',
#        'Falmouth University', 'City, University of London',
#        'De Montfort University', 'University of Central Lancashire',
#        'Plymouth University', 'University of Hull',
#        'Liverpool John Moores University', 'University of Chester',
#        'University of the Arts London', 'York St John University',
#        'Queen Margaret University', 'Robert Gordon University',
#        'University of Greenwich', "St Mary's University, Twickenham",
#        'London South Bank University', 'Teesside University',
#        'University of Hertfordshire', 'Royal Agricultural University',
#        'Solent University', 'University of Derby',
#        'University of Buckingham', 'University of Worcester',
#        'Bournemouth University', 'University of Gloucestershire',
#        'Birmingham City University', 'Glasgow Caledonian University',
#        'University of Winchester', 'Abertay University',
#        'Brunel University London', 'Edinburgh Napier University',
#        'University of Wales Trinity Saint David',
#        'Bishop Grosseteste University', 'Plymouth Marjon University',
#        'University of Bradford', 'Kingston University',
#        'Middlesex University', 'University of the West of Scotland',
#        'University of Sunderland', 'Bath Spa University',
#        'University of Salford', 'Cardiff Metropolitan University',
#        'Buckinghamshire New University', 'University of South Wales',
#        'Newman University', 'University of Northampton',
#        'Leeds Trinity University', 'Canterbury Christ Church University',
#        'University of Westminster', 'Anglia Ruskin University',
#        'University of Cumbria', 'University of Brighton',
#        'Leeds Beckett University', 'University of Wolverhampton',
#        'University of Bolton', 'London Metropolitan University',
#        'University of East London', 'University of Bedfordshire',
#        'University of Suffolk', 'Wrexham Glyndwr University',
#        'Ravensbourne University London'], dtype=object)

# %%
unis.iloc[0] #returns a single row by index
# Out:
# University_name                                               University of Cambridge
# Region                                                                East of England
# Founded_year                                                                     1209
# Motto                                            From here, light and sacred draughts
# UK_rank                                                                             1
# World_rank                                                                          4
# CWUR_score                                                                       94.1
# Minimum_IELTS_score                                                               6.5
# UG_average_fees_(in_pounds)                                                     21750
# PG_average_fees_(in_pounds)                                                     23187
# International_students                                                         20.20%
# Student_satisfaction                                                           85.50%
# Student_enrollment                                                      20,000-24,999
# Academic_staff                                                             over-5,000
# Control_type                                                                   Public
# Academic_Calender                                                          Trimesters
# Campus_setting                                                                  Urban
# Estimated_cost_of_living_per_year_(in_pounds)                                   12000
# Latitude                                                                      52.2054
# Longitude                                                                      0.1132
# Website                                                                 www.cam.ac.uk
# Name: 0, dtype: object

# %%
unis.iloc[[0,1,2,3,10,12]]
# Out:
#              University_name                    Region  Founded_year  \
# 0    University of Cambridge           East of England          1209
# 1       University of Oxford        South East England          1096
# 2   University of St Andrews                  Scotland          1413
# 3    Imperial College London                    London          1907
# 10        University of Bath        South West England          1966
# 12       University of Leeds  Yorkshire and the Humber          1904
#
#                                                 Motto  UK_rank  World_rank  \
# 0                From here, light and sacred draughts        1           4
# 1                                The Lord is my light        2           2
# 2                                       Ever to excel        3          86
# 3   Knowledge is the adornment and safeguard of th...        4           8
# 10    Learn each field of study according to its kind       11         261
# 12                    And Knowledge Will Be Increased       13         133
#
#     CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0         94.1                  6.5                        21750
# 1         93.3                  6.5                        21770
# 2         75.8                  6.5                        17040
# 3         86.6                  6.5                        23500
# 10        74.8                  5.5                        14300
# 12        81.6                  5.5                        13500
#
#     PG_average_fees_(in_pounds)  ... Student_satisfaction Student_enrollment  \
# 0                         23187  ...               85.50%      20,000-24,999
# 1                         19888  ...               86.50%      25,000-29,999
# 2                         15440  ...               87.90%      10,000-14,999
# 3                         29900  ...               77.90%      15,000-19,999
# 10                        15000  ...               81.80%      15,000-19,999
# 12                        14000  ...               80.40%      35,000-39,999
#
#    Academic_staff Control_type Academic_Calender Campus_setting  \
# 0      over-5,000       Public        Trimesters          Urban
# 1      over-5,000       Public        Trimesters          Urban
# 2     1,000-1,499       Public         Semesters       Suburban
# 3     4,000-4,499       Public        Continuous          Urban
# 10    1,000-1,499       Public         Semesters       Suburban
# 12    3,500-3,999       Public         Semesters          Urban
#
#    Estimated_cost_of_living_per_year_(in_pounds)  Latitude  Longitude  \
# 0                                          12000   52.2054     0.1132
# 1                                          11500   51.7548    -1.2544
# 2                                          12000   56.3417    -2.7943
# 3                                          10700   51.4988    -0.1749
# 10                                         11000   51.3782    -2.3264
# 12                                          7000   53.8067    -1.5550
#
#                  Website
# 0          www.cam.ac.uk
# 1           www.ox.ac.uk
# 2   www.st-andrews.ac.uk
# 3           www.ic.ac.uk
# 10        www.bath.ac.uk
# 12       www.leeds.ac.uk
#
# [6 rows x 21 columns]

# %%
unis.loc[[0]]
# Out:
#            University_name           Region  Founded_year  \
# 0  University of Cambridge  East of England          1209
#
#                                   Motto  UK_rank  World_rank  CWUR_score  \
# 0  From here, light and sacred draughts        1           4        94.1
#
#    Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0                  6.5                        21750
#
#    PG_average_fees_(in_pounds)  ... Student_satisfaction Student_enrollment  \
# 0                        23187  ...               85.50%      20,000-24,999
#
#   Academic_staff Control_type Academic_Calender Campus_setting  \
# 0     over-5,000       Public        Trimesters          Urban
#
#   Estimated_cost_of_living_per_year_(in_pounds)  Latitude  Longitude  \
# 0                                         12000   52.2054     0.1132
#
#          Website
# 0  www.cam.ac.uk
#
# [1 rows x 21 columns]

# %%
unis = unis.set_index('University_name') #setting an index

# %%
unis.loc['University of Cambridge']
# Out:
# Region                                                                East of England
# Founded_year                                                                     1209
# Motto                                            From here, light and sacred draughts
# UK_rank                                                                             1
# World_rank                                                                          4
# CWUR_score                                                                       94.1
# Minimum_IELTS_score                                                               6.5
# UG_average_fees_(in_pounds)                                                     21750
# PG_average_fees_(in_pounds)                                                     23187
# International_students                                                         20.20%
# Student_satisfaction                                                           85.50%
# Student_enrollment                                                      20,000-24,999
# Academic_staff                                                             over-5,000
# Control_type                                                                   Public
# Academic_Calender                                                          Trimesters
# Campus_setting                                                                  Urban
# Estimated_cost_of_living_per_year_(in_pounds)                                   12000
# Latitude                                                                      52.2054
# Longitude                                                                      0.1132
# Website                                                                 www.cam.ac.uk
# Name: University of Cambridge, dtype: object

# %%
unis.index # 'University of Cambridge' in unis.index
# Out:
# Index(['University of Cambridge', 'University of Oxford',
#        'University of St Andrews', 'Imperial College London',
#        'Loughborough University',
#        'London School of Economics and Political Science', 'Durham University',
#        'Lancaster University', 'University College London',
#        'University of Warwick',
#        ...
#        'University of Brighton', 'Leeds Beckett University',
#        'University of Wolverhampton', 'University of Bolton',
#        'London Metropolitan University', 'University of East London',
#        'University of Bedfordshire', 'University of Suffolk',
#        'Wrexham Glyndwr University', 'Ravensbourne University London'],
#       dtype='object', name='University_name', length=131)

# %%
unis = unis.reset_index() #should you change your mind

# %%
unis['University_name'].replace('University of Cambridge', 'Harvard')
# Out:
# 0                             Harvard
# 1                University of Oxford
# 2            University of St Andrews
# 3             Imperial College London
# 4             Loughborough University
#                     ...
# 126         University of East London
# 127        University of Bedfordshire
# 128             University of Suffolk
# 129        Wrexham Glyndwr University
# 130    Ravensbourne University London
# Name: University_name, Length: 131, dtype: object

# %%
unis['Campus_setting'].replace({'Urban' : 'Urbann', 'Suburban' : 'yes'})
# Out:
# 0      Urbann
# 1      Urbann
# 2         yes
# 3      Urbann
# 4         yes
#         ...
# 126       yes
# 127    Urbann
# 128       NaN
# 129    Urbann
# 130    Urbann
# Name: Campus_setting, Length: 131, dtype: object

# %%
mask = unis['Campus_setting'] == 'Urban'
mask.sum()
# Out:
# 68

# %%
unis.loc[mask, 'Region'] = 'East of England'

# %%
unis
# Out:
#      level_0  index                 University_name           Region  \
# 0          0      0         University of Cambridge  East of England
# 1          1      1            University of Oxford  East of England
# 2          2      2        University of St Andrews         Scotland
# 3          3      3         Imperial College London  East of England
# 4          4      4         Loughborough University    East Midlands
# ..       ...    ...                             ...              ...
# 126      126    126       University of East London           London
# 127      127    127      University of Bedfordshire  East of England
# 128      128    128           University of Suffolk  East of England
# 129      129    129      Wrexham Glyndwr University  East of England
# 130      130    130  Ravensbourne University London  East of England
#
#      Founded_year                                              Motto  UK_rank  \
# 0            1209               From here, light and sacred draughts        1
# 1            1096                               The Lord is my light        2
# 2            1413                                      Ever to excel        3
# 3            1907  Knowledge is the adornment and safeguard of th...        4
# 4            1966                   With Truth, Knowledge and Labour        5
# ..            ...                                                ...      ...
# 126          1992                    Science and fulfillment of vows      127
# 127          2006                                           No motto      128
# 128          2007                              Honesty and diligence      129
# 129          2008                       Confidence through Education      130
# 130          1962                              Designed for industry      131
#
#      World_rank  CWUR_score  Minimum_IELTS_score  ...  Student_satisfaction  \
# 0             4        94.1                  6.5  ...                85.50%
# 1             2        93.3                  6.5  ...                86.50%
# 2            86        75.8                  6.5  ...                87.90%
# 3             8        86.6                  6.5  ...                77.90%
# 4           404        72.8                  5.5  ...                85.80%
# ..          ...         ...                  ...  ...                   ...
# 126         971         NaN                  4.5  ...                76.10%
# 127        1281         NaN                  4.5  ...                77.40%
# 128        4030         NaN                  4.5  ...                76.00%
# 129        2397         NaN                  4.5  ...                74.30%
# 130        2759         NaN                  5.5  ...                66.10%
#
#      Student_enrollment Academic_staff Control_type Academic_Calender  \
# 0         20,000-24,999     over-5,000       Public        Trimesters
# 1         25,000-29,999     over-5,000       Public        Trimesters
# 2         10,000-14,999    1,000-1,499       Public         Semesters
# 3         15,000-19,999    4,000-4,499       Public        Continuous
# 4         15,000-19,999    1,500-1,999       Public         Semesters
# ..                  ...            ...          ...               ...
# 126       10,000-14,999        900-999       Public         Semesters
# 127       10,000-14,999        500-599       Public         Semesters
# 128         7,000-7,999        200-299       Public               NaN
# 129         5,000-5,999        200-299       Public               NaN
# 130         2,000-2,999        100-199       Public         Semesters
#
#     Campus_setting Estimated_cost_of_living_per_year_(in_pounds) Latitude  \
# 0            Urban                                         12000  52.2054
# 1            Urban                                         11500  51.7548
# 2         Suburban                                         12000  56.3417
# 3            Urban                                         10700  51.4988
# 4         Suburban                                          9398  52.7650
# ..             ...                                           ...      ...
# 126       Suburban                                         10229  51.5076
# 127          Urban                                          9415  51.8779
# 128            NaN                                          9415  52.0523
# 129          Urban                                          7771  53.0526
# 130          Urban                                         10229  51.5017
#
#     Longitude                 Website
# 0      0.1132           www.cam.ac.uk
# 1     -1.2544            www.ox.ac.uk
# 2     -2.7943    www.st-andrews.ac.uk
# 3     -0.1749            www.ic.ac.uk
# 4     -1.2321        www.lboro.ac.uk/
# ..        ...                     ...
# 126    0.0651           www.uel.ac.uk
# 127   -0.4093          www.beds.ac.uk
# 128    1.1629          www.ucs.ac.uk/
# 129   -3.0062      www.glyndwr.ac.uk/
# 130    0.0055  www.ravensbourne.ac.uk
#
# [131 rows x 23 columns]

# %%
#unis = unis.set_index('University_name') #setting an index
unis = unis.reset_index()
unis = unis.rename(index = {'Ravensbourne University London' : 'RUL'}, columns={'University_name' : 'Name'})

# %%
unis
# Out:
#                            Name           Region  Founded_year  \
# 0       University of Cambridge  East of England          1209
# 1          University of Oxford  East of England          1096
# 2      University of St Andrews         Scotland          1413
# 3       Imperial College London  East of England          1907
# 4       Loughborough University    East Midlands          1966
# ..                          ...              ...           ...
# 126   University of East London           London          1992
# 127  University of Bedfordshire  East of England          2006
# 128       University of Suffolk  East of England          2007
# 129  Wrexham Glyndwr University  East of England          2008
# 130                         RUL  East of England          1962
#
#                                                  Motto  UK_rank  World_rank  \
# 0                 From here, light and sacred draughts        1           4
# 1                                 The Lord is my light        2           2
# 2                                        Ever to excel        3          86
# 3    Knowledge is the adornment and safeguard of th...        4           8
# 4                     With Truth, Knowledge and Labour        5         404
# ..                                                 ...      ...         ...
# 126                    Science and fulfillment of vows      127         971
# 127                                           No motto      128        1281
# 128                              Honesty and diligence      129        4030
# 129                       Confidence through Education      130        2397
# 130                              Designed for industry      131        2759
#
#      CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0          94.1                  6.5                        21750
# 1          93.3                  6.5                        21770
# 2          75.8                  6.5                        17040
# 3          86.6                  6.5                        23500
# 4          72.8                  5.5                        16400
# ..          ...                  ...                          ...
# 126         NaN                  4.5                        10700
# 127         NaN                  4.5                         9750
# 128         NaN                  4.5                         9495
# 129         NaN                  4.5                        10250
# 130         NaN                  5.5                         9250
#
#      PG_average_fees_(in_pounds)  ... Student_satisfaction Student_enrollment  \
# 0                          23187  ...               85.50%      20,000-24,999
# 1                          19888  ...               86.50%      25,000-29,999
# 2                          15440  ...               87.90%      10,000-14,999
# 3                          29900  ...               77.90%      15,000-19,999
# 4                          16400  ...               85.80%      15,000-19,999
# ..                           ...  ...                  ...                ...
# 126                        11700  ...               76.10%      10,000-14,999
# 127                         9900  ...               77.40%      10,000-14,999
# 128                         9495  ...               76.00%        7,000-7,999
# 129                        10500  ...               74.30%        5,000-5,999
# 130                         9250  ...               66.10%        2,000-2,999
#
#     Academic_staff Control_type Academic_Calender Campus_setting  \
# 0       over-5,000       Public        Trimesters          Urban
# 1       over-5,000       Public        Trimesters          Urban
# 2      1,000-1,499       Public         Semesters       Suburban
# 3      4,000-4,499       Public        Continuous          Urban
# 4      1,500-1,999       Public         Semesters       Suburban
# ..             ...          ...               ...            ...
# 126        900-999       Public         Semesters       Suburban
# 127        500-599       Public         Semesters          Urban
# 128        200-299       Public               NaN            NaN
# 129        200-299       Public               NaN          Urban
# 130        100-199       Public         Semesters          Urban
#
#     Estimated_cost_of_living_per_year_(in_pounds)  Latitude  Longitude  \
# 0                                           12000   52.2054     0.1132
# 1                                           11500   51.7548    -1.2544
# 2                                           12000   56.3417    -2.7943
# 3                                           10700   51.4988    -0.1749
# 4                                            9398   52.7650    -1.2321
# ..                                            ...       ...        ...
# 126                                         10229   51.5076     0.0651
# 127                                          9415   51.8779    -0.4093
# 128                                          9415   52.0523     1.1629
# 129                                          7771   53.0526    -3.0062
# 130                                         10229   51.5017     0.0055
#
#                     Website
# 0             www.cam.ac.uk
# 1              www.ox.ac.uk
# 2      www.st-andrews.ac.uk
# 3              www.ic.ac.uk
# 4          www.lboro.ac.uk/
# ..                      ...
# 126           www.uel.ac.uk
# 127          www.beds.ac.uk
# 128          www.ucs.ac.uk/
# 129      www.glyndwr.ac.uk/
# 130  www.ravensbourne.ac.uk
#
# [131 rows x 21 columns]

# %% [markdown]
# ## Lambdas

# %%
unis['Name'].apply(len) #astype(str) if any type errors occur
# Out:
# 0      23
# 1      20
# 2      24
# 3      23
# 4      23
#        ..
# 126    25
# 127    26
# 128    21
# 129    26
# 130     3
# Name: Name, Length: 131, dtype: int64

# %%
unis['Name'].apply(lambda x : len(x))
# Out:
# 0      23
# 1      20
# 2      24
# 3      23
# 4      23
#        ..
# 126    25
# 127    26
# 128    21
# 129    26
# 130     3
# Name: Name, Length: 131, dtype: int64

# %%
def make_double(x):
    if type(x) == str:
        x = x + " " + x
    if type(x) == int:
        x = x * 2
    return x

unis['Name'].apply(lambda x : make_double(x))
#or unis.apply(lambda x : make_double(x['Name']), axis = 1)
# Out:
# 0        University of Cambridge University of Cambridge
# 1              University of Oxford University of Oxford
# 2      University of St Andrews University of St Andrews
# 3        Imperial College London Imperial College London
# 4        Loughborough University Loughborough University
#                              ...
# 126    University of East London University of East L...
# 127    University of Bedfordshire University of Bedfo...
# 128          University of Suffolk University of Suffolk
# 129    Wrexham Glyndwr University Wrexham Glyndwr Uni...
# 130                                              RUL RUL
# Length: 131, dtype: object

# %%
def combine(x,y):
    return str(x) + " " + str(y)

unis.apply(lambda x : combine(x['Name'], x['Region']), axis = 1)
# Out:
# 0         University of Cambridge East of England
# 1            University of Oxford East of England
# 2               University of St Andrews Scotland
# 3         Imperial College London East of England
# 4           Loughborough University East Midlands
#                           ...
# 126              University of East London London
# 127    University of Bedfordshire East of England
# 128         University of Suffolk East of England
# 129    Wrexham Glyndwr University East of England
# 130                           RUL East of England
# Length: 131, dtype: object

# %%
unis.describe()
#unis.groupby('Minimum_IELTS_score').mean()
unis['World_rank'] = unis['World_rank'].astype(float)
#unis.groupby('Name').mean().sort_values('World_rank', ascending = False) ...??? doesnt work
unis.groupby('Name').agg({'World_rank': ['mean', 'max']})
#unis.groupby('Name').groups.keys()
#unis.groupby('Region').get_group('East of England')
# Out:
#                                                  Name           Region  \
# 0                             University of Cambridge  East of England
# 1                                University of Oxford  East of England
# 3                             Imperial College London  East of England
# 5    London School of Economics and Political Science  East of England
# 6                                   Durham University  East of England
# ..                                                ...              ...
# 125                    London Metropolitan University  East of England
# 127                        University of Bedfordshire  East of England
# 128                             University of Suffolk  East of England
# 129                        Wrexham Glyndwr University  East of England
# 130                                               RUL  East of England
#
#      Founded_year                                              Motto  UK_rank  \
# 0            1209               From here, light and sacred draughts        1
# 1            1096                               The Lord is my light        2
# 3            1907  Knowledge is the adornment and safeguard of th...        4
# 5            1895                       To know the causes of things        6
# 6            1832            Her foundations are upon the holy hills        7
# ..            ...                                                ...      ...
# 125          1848                             Knowledge in Abundance      126
# 127          2006                                           No motto      128
# 128          2007                              Honesty and diligence      129
# 129          2008                       Confidence through Education      130
# 130          1962                              Designed for industry      131
#
#      World_rank  CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0           4.0        94.1                  6.5                        21750
# 1           2.0        93.3                  6.5                        21770
# 3           8.0        86.6                  6.5                        23500
# 5          23.0        76.3                  6.5                        17040
# 6          70.0        76.3                  5.5                        14900
# ..          ...         ...                  ...                          ...
# 125      1025.0         NaN                  4.5                        11400
# 127      1281.0         NaN                  4.5                         9750
# 128      4030.0         NaN                  4.5                         9495
# 129      2397.0         NaN                  4.5                        10250
# 130      2759.0         NaN                  5.5                         9250
#
#      PG_average_fees_(in_pounds)  ... Student_satisfaction Student_enrollment  \
# 0                          23187  ...               85.50%      20,000-24,999
# 1                          19888  ...               86.50%      25,000-29,999
# 3                          29900  ...               77.90%      15,000-19,999
# 5                          24500  ...               68.50%      10,000-14,999
# 6                          18000  ...               75.00%      15,000-19,999
# ..                           ...  ...                  ...                ...
# 125                        13500  ...               75.70%        9,000-9,999
# 127                         9900  ...               77.40%      10,000-14,999
# 128                         9495  ...               76.00%        7,000-7,999
# 129                        10500  ...               74.30%        5,000-5,999
# 130                         9250  ...               66.10%        2,000-2,999
#
#     Academic_staff Control_type Academic_Calender Campus_setting  \
# 0       over-5,000       Public        Trimesters          Urban
# 1       over-5,000       Public        Trimesters          Urban
# 3      4,000-4,499       Public        Continuous          Urban
# 5      1,500-1,999       Public         Semesters          Urban
# 6      1,500-1,999       Public        Trimesters          Urban
# ..             ...          ...               ...            ...
# 125        400-499       Public        Continuous          Urban
# 127        500-599       Public         Semesters          Urban
# 128        200-299       Public               NaN            NaN
# 129        200-299       Public               NaN          Urban
# 130        100-199       Public         Semesters          Urban
#
#     Estimated_cost_of_living_per_year_(in_pounds)  Latitude  Longitude  \
# 0                                           12000   52.2054     0.1132
# 1                                           11500   51.7548    -1.2544
# 3                                           10700   51.4988    -0.1749
# 5                                           12000   51.5144    -0.1165
# 6                                            8000   54.7650    -1.5782
# ..                                            ...       ...        ...
# 125                                         15000   51.5526    -0.1113
# 127                                          9415   51.8779    -0.4093
# 128                                          9415   52.0523     1.1629
# 129                                          7771   53.0526    -3.0062
# 130                                         10229   51.5017     0.0055
#
#                     Website
# 0             www.cam.ac.uk
# 1              www.ox.ac.uk
# 3              www.ic.ac.uk
# 5             www.lse.ac.uk
# 6             www.dur.ac.uk
# ..                      ...
# 125     www.londonmet.ac.uk
# 127          www.beds.ac.uk
# 128          www.ucs.ac.uk/
# 129      www.glyndwr.ac.uk/
# 130  www.ravensbourne.ac.uk
#
# [72 rows x 21 columns]

# %% [markdown]
# ## Sets
# I personally don't have two datasets that I could use for demonstrating set operations but I'll leave the functions here
# <br>Let's say we have database A and B
# <br><code>pd.concat([week1,week2], ignore_index=True, axis=1)<code>
# <br><code>databaseA.merge(databaseB, on='ID1', suffixes=['-databaseA','-databaseB'])<code>
# <br> The suffixes provide a clearer distinction when creating the view
# <br><code>databaseA.merge(databaseB, on=['ID1', 'ID2'], how='outer')<code>
# <br><code>databaseA.merge(customers, how='left', left_on='ID1', right_on='ID')</code>
#
# <br><code>databaseA.join(databaseC.set_index('ID'), on='Customer ID')</code> Join and merge are similar

# %% [markdown]
# ## Working with datetime

# %%
import datetime as dt

# %%
someday = dt.date(2019, 1, 1)

# %%
someday.year, someday.month
# Out:
# (2019, 1)

# %%
someday = pd.to_datetime('2019-10-21') #YYYY-MM-DD
someday
# Out:
# Timestamp('2019-10-21 00:00:00')

# %%
pd.Timestamp('2019-10-21 01:13:21')
# Out:
# Timestamp('2019-10-21 01:13:21')

# %%
dates = ['2023-10-01', '2023-10-02', 'NaN', 'hello']
pd.to_datetime(dates, errors='coerce')
# Out:
# DatetimeIndex(['2023-10-01', '2023-10-02', 'NaT', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
pd.date_range('2023-10-02', '2023-11-01', freq='D') #2D, M, etc.
# Out:
# DatetimeIndex(['2023-10-02', '2023-10-03', '2023-10-04', '2023-10-05',
#                '2023-10-06', '2023-10-07', '2023-10-08', '2023-10-09',
#                '2023-10-10', '2023-10-11', '2023-10-12', '2023-10-13',
#                '2023-10-14', '2023-10-15', '2023-10-16', '2023-10-17',
#                '2023-10-18', '2023-10-19', '2023-10-20', '2023-10-21',
#                '2023-10-22', '2023-10-23', '2023-10-24', '2023-10-25',
#                '2023-10-26', '2023-10-27', '2023-10-28', '2023-10-29',
#                '2023-10-30', '2023-10-31', '2023-11-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2024-06-30', periods=10, freq='2D')
# Out:
# DatetimeIndex(['2024-06-30', '2024-07-02', '2024-07-04', '2024-07-06',
#                '2024-07-08', '2024-07-10', '2024-07-12', '2024-07-14',
#                '2024-07-16', '2024-07-18'],
#               dtype='datetime64[ns]', freq='2D')

# %% [markdown]
# ## Read Stock Data from Yahoo finance

# %%
# !pip install pandas_datareader

# %%
# !pip show pandas-datareader
# Out:
# Name: pandas-datareader
# Version: 0.10.0
# Summary: Data readers extracted from the pandas codebase,should be compatible with recent pandas versions
# Home-page: https://github.com/pydata/pandas-datareader
# Author: The PyData Development Team
# Author-email: pydata@googlegroups.com
# License: BSD License
# Location: F:\Programs\Anaconda\Lib\site-packages
# Requires: lxml, pandas, requests
# Required-by:

# %%
import pandas_datareader.data as web

# %%
start = pd.to_datetime('2024-06-29')
end = pd.to_datetime('2024-07-01')
data = web.DataReader('TSLA', 'yahoo', start, end) #temporary issue with yahoo finance api (server side error)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[472], line 3
#       1 start = pd.to_datetime('2024-06-29')
#       2 end = pd.to_datetime('2024-07-01')
# ----> 3 data = web.DataReader('TSLA', 'yahoo', start, end)
#
# File F:\Programs\Anaconda\Lib\site-packages\pandas\util\_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# File F:\Programs\Anaconda\Lib\site-packages\pandas_datareader\data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
#     375         chunksize=25,
#     376         retry_count=retry_count,
#     377         pause=pause,
#     378         session=session,
# --> 379     ).read()
#     381 elif data_source == "iex":
#     382     return IEXDailyReader(
#     383         symbols=name,
#     384         start=start,
#    (...)
#     390         session=session,
#     391     ).read()
#
# File F:\Programs\Anaconda\Lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# File F:\Programs\Anaconda\Lib\site-packages\pandas_datareader\yahoo\daily.py:152, in YahooDailyReader._read_one_data(self, url, params)
#     150 ptrn = r"root\.App\.main = (.*?);\n}\(this\)\);"
#     151 try:
# --> 152     j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
#     153     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154 except KeyError:
#
# AttributeError: 'NoneType' object has no attribute 'group'
